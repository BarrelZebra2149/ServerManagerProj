# %% [markdown]
# ## A. 부팅 설정
#
# 1. 리눅스 ISO 다운로드
# 2. Rufus 다운로드
# 3. Start, 자동으로 USB에 부팅 파일 설치.
#
# ## B. Ubuntu Server 설치 화면
#
# 1. **부팅 화면에서 OpenSSL을 꼭 설치할 것.** 나머지는 편하게 설치하면 됨
# 2. 가끔씩 서버에서 몇몇개를 설치를 못하는데, 재부팅 하면 전부 해결됨.
#
# ## C. Ubuntu Server 화면
#
# 로그인 이후 아래 명령 실행.

# %%
# !apt list openssh*
