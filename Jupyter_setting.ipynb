# %% [markdown]
# ## Open Jupyter from Linux Server
# This notebook guides how to open Jupyter from Linux Server.

# %% [markdown]
# ## A. install Python

# %%
# !sudo apt list | grep python
# !sudo apt install python[latest_version]
# !apt list --installed | grep python
# !sudo apt install python-is-python3
# !python -V

# %% [markdown]
# ## B. configure Venv

# %%
# !sudo apt-get update
# !sudo apt install python[latest_version]-venv
# !cd ~
# !python -m venv JupyterLAB
# !source JupyterLAB/bin/activate
# !pip install --upgrade pip

# %% [markdown]
# ## C. configure JupyterLAB

# %%
# !pip install jupyterlab
# !jupyter server --generate-config
# !jupyter server password

# %% [markdown]
# now use `jupyter_lab_execute.sh` on ssh

# %% [markdown]
# ## Error : Can't kill Jupyter Process
# use this below.

# %%
# !pkill -9 -u $USER -f jupyter
